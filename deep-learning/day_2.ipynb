# %% [markdown]
# <a href="https://colab.research.google.com/github/musharrafhamraz/deep-learning-uconnect/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow   

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# Sample input data (study hours, sleep hours)
X = np.array([[2, 9], [1, 5], [3, 6], [4, 8]])
y = np.array([[0], [0], [1], [1]])  # 0 = fail, 1 = pass
# Out:
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
# Define the model
model = Sequential([
    Dense(3, input_dim=2, activation='relu'),  # Hidden layer
    Dense(1, activation='sigmoid')             # Output layer
])

# Compile and train
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
# ...

# %%
model.fit(X, y, epochs=100, verbose=1)

# Forward propagation (making predictions)
predictions = model.predict(X)
print(predictions)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step - accuracy: 0.5000 - loss: 2.3870
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 2.3746
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 2.3622
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 2.3499
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 2.3375
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 2.3252
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 2.3128
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 2.3005
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 2.2882
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 2.2759
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 2.2635
# Epoch 12/100
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Create a toy dataset
X, y = make_moons(n_samples=500, noise=0.2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Compare different activations
activations = ['sigmoid', 'tanh', 'relu']
history_records = {}

for act in activations:
    model = Sequential([
        Dense(8, input_dim=2, activation=act),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                        epochs=100, verbose=1)
    history_records[act] = history.history['val_accuracy']

# Plot comparison
for act in activations:
    plt.plot(history_records[act], label=f'{act}')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Activation Function Comparison')
plt.show()
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5159 - loss: 0.7270 - val_accuracy: 0.4733 - val_loss: 0.7571
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5374 - loss: 0.7002 - val_accuracy: 0.4733 - val_loss: 0.7434
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5044 - loss: 0.7105 - val_accuracy: 0.4733 - val_loss: 0.7306
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5130 - loss: 0.6981 - val_accuracy: 0.4733 - val_loss: 0.7199
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5247 - loss: 0.6788 - val_accuracy: 0.4733 - val_loss: 0.7097
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4940 - loss: 0.6902 - val_accuracy: 0.4733 - val_loss: 0.7005
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5227 - loss: 0.6656 - val_accuracy: 0.4733 - val_loss: 0.6921
# Epoch 8/100
# ...

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
# Out:
# 2025-10-24 16:25:46.778572: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-24 16:25:47.284983: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-24 16:25:49.114321: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
X, y = make_regression(n_samples=500, n_features=1, noise=15, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

losses = ['mse', 'mae']
histories = {}

for loss_func in losses:
    model = Sequential([
        Dense(8, input_dim=1, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss=loss_func)
    history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test))
    histories[loss_func] = history.history['val_loss']

plt.plot(histories['mse'], label='MSE')
plt.plot(histories['mae'], label='MAE')
plt.legend()
plt.title('MSE vs MAE Comparison')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.show()
